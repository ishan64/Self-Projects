# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('drug200.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# Plots

# %% [markdown]
# Age -- Drug

# %%
plt.figure(figsize = (9,5))
sns.swarmplot(x = "Drug", y = "Age",data = dataset)
plt.legend(dataset.Drug.value_counts().index)
plt.title("Age -- Drug")
plt.show()

# %% [markdown]
# Sex -- Drug

# %%
df_Sex_Drug = dataset.groupby(["Drug","Sex"]).size().reset_index(name = "Count")
df_Sex_Drug
plt.figure(figsize = (9,5))
sns.barplot(x = "Drug",y="Count", hue = "Sex",data = df_Sex_Drug)
plt.title("Sex -- Drug")
plt.show()

# %% [markdown]
# BP -- Drug

# %%
df_BP_Drug = dataset.groupby(["Drug","BP"]).size().reset_index(name = "Count")
df_BP_Drug
plt.figure(figsize = (9,5))
sns.barplot(x = "Drug",y="Count", hue = "BP",data = df_BP_Drug)
plt.title("BP -- Drug")
plt.show()

# %% [markdown]
# Na_to_K -- Drug

# %%
plt.figure(figsize = (9,5))
sns.swarmplot(x = "Drug", y = "Na_to_K",data = dataset)
plt.title("Na_to_K -- Drug")
plt.show()

# %% [markdown]
# Chlorestrol -- Drug

# %%
df_CH_Drug = dataset.groupby(["Drug","Cholesterol"]).size().reset_index(name = "Count")
df_CH_Drug
plt.figure(figsize = (9,5))
sns.barplot(x = "Drug",y="Count", hue = "Cholesterol",data = df_CH_Drug)
plt.title("Cholesterol -- Drug")
plt.show()

# %% [markdown]
# Na_to_K -- BP -- Drug

# %%
plt.figure(figsize = (9,5))
sns.swarmplot(x = "Drug", y = "Na_to_K",hue="BP",data = dataset)
plt.legend()
plt.title("Na_to_K -- BP -- Drug")
plt.show()

# %% [markdown]
# Label Encoding on Drug Type

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:, 1] = le.fit_transform(X[:, 1])
X[:, 2] = le.fit_transform(X[:, 2])
X[:, 3] = le.fit_transform(X[:, 3])
y = le.fit_transform(y)
print(X)
# Out:
# [[23 0 0 0 25.355]
#  [47 1 1 0 13.093]
#  [47 1 1 0 10.114]
#  [28 0 2 0 7.798]
#  [61 0 1 0 18.043]
#  [22 0 2 0 8.607]
#  [49 0 2 0 16.275]
#  [41 1 1 0 11.037]
#  [60 1 2 0 15.171]
#  [43 1 1 1 19.368]
#  [47 0 1 0 11.767]
#  [34 0 0 1 19.199]
#  [43 1 1 0 15.376]
#  [74 0 1 0 20.942]
#  [50 0 2 0 12.703]
#  [16 0 0 1 15.516]
#  [69 1 1 1 11.455]
#  [43 1 0 0 13.972]
#  [23 1 1 0 7.298]
#  [32 0 0 1 25.974]
#  [57 1 1 1 19.128]
#  [63 1 2 0 25.917]
#  [47 1 1 1 30.568]
#  [48 0 1 0 15.036]
#  [33 0 1 0 33.486]
#  [28 0 0 1 18.809]
#  [31 1 0 0 30.366]
#  [49 0 2 1 9.381]
#  [39 0 1 1 22.697]
#  [45 1 1 0 17.951]
#  [18 0 2 1 8.75]
#  [74 1 0 0 9.567]
#  [49 1 1 1 11.014]
#  [65 0 0 1 31.876]
#  [53 1 2 0 14.133]
#  [46 1 2 1 7.285]
#  [32 1 0 1 9.445]
#  [39 1 1 1 13.938]
#  [39 0 2 1 9.709]
#  [15 1 2 0 9.084]
#  [73 0 2 0 19.221]
#  [58 0 0 1 14.239]
#  [50 1 2 1 15.79]
#  [23 1 2 0 12.26]
#  [50 0 2 1 12.295]
#  [66 0 2 1 8.107]
#  [37 0 0 0 13.091]
#  [68 1 1 0 10.291]
# ...

# %%
print(y)
# Out:
# [0 3 3 4 0 4 0 3 0 0 3 0 0 0 4 0 4 1 3 0 0 0 0 0 0 0 0 4 0 0 4 2 4 0 4 4 1
#  4 4 4 0 2 0 4 4 4 1 3 0 0 0 4 0 0 2 3 2 0 4 0 0 1 0 4 2 0 1 4 0 0 2 0 4 0
#  0 0 1 0 1 4 2 4 3 1 3 2 4 0 0 0 0 0 0 0 0 4 0 0 0 0 1 1 3 4 0 4 4 0 2 0 1
#  4 4 4 4 0 4 4 1 0 0 0 0 0 2 0 0 4 0 4 0 0 4 0 0 4 2 1 2 4 1 0 2 0 1 4 4 1
#  4 3 1 2 4 4 0 3 1 0 3 4 4 2 4 0 0 0 0 4 0 1 4 4 0 0 1 0 1 0 0 0 0 4 4 0 0
#  0 2 1 0 0 0 1 0 3 0 3 3 4 4 4]

# %% [markdown]
# Splitting the dataset into test set and Training set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %% [markdown]
# Feature Scaling on the dataset

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# Training the dataset on a classification model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
classifier.fit(X_train , y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=42)

# %% [markdown]
# Predicting the Test Set results

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# Making the Confusion Matrix

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[29  0  0  0  0]
#  [ 0  8  0  0  0]
#  [ 0  0  4  0  0]
#  [ 0  0  0  4  2]
#  [ 0  0  0  0 19]]
# 0.9696969696969697
